# %% [markdown]
# # CURSO 2 - CIENCIA DE DADOS E APRENDIZADO DE MÁQUINA
# ## PROFa. Roseli A F Romero
#
# # Segunda avaliação quinzenal
# #Tópico abordado:
# # **CLASSIFICADORES DE AM**
# - DT, RF, XGB,
# - SVM, NB, KNN
#
#
# ### Questão 01.
#
# Para essa questão, utilize o dataset Wine (`sklearn.datasets.load_wine`).
# - Separe o conjunto em 80% treino e 20% teste (utilize `random_state=0`)
# - Treine uma arvore de decisão (`sklearn.tree.DecisionTreeClassifier`) com parâmetros padrão e `random_state=0` no conjunto de treino
# - Plote a árvore de decisão
#
# Visualizando a árvore de decisão, responda: qual o caminho mais curto possível, a partir do nó raiz, para que essa árvore classifique um novo exemplo?
#
# - Dica: Lembre-se que se a condição em um nó é verdadeira, o próximo nó avaliado será o nó da esquerda. Se for falsa, será o da direita.
#
# a) X[9] <= 3.46 $\rightarrow$ X[6] <= 2.11 $\rightarrow$ Classe 0<br>
# b) X[9] <= 3.46 $\rightarrow$ Classe 1<br>
# c) X[6] <= 2.11 $\rightarrow$ Classe 2<br>
# d) X[0] <= 12.785 $\rightarrow$ Classe 1

# %% [markdown]
# ---
# ### Questão 02.
#
# Considere a matriz de confusão abaixo:
#
# <img style="width: 350px;" src="data:image/png;base64,..." />
#
#
# Com base nos slides vistos em aula, o recall e a precisão para essa matriz são, respectivamente (utilize duas casas decimais):
#
# a) recall: **0.9**, precisão: **0.9**<br>
# b) recall: **0.25**, precisão: **0.75**<br>
# c) recall: **0.45**, precisão: **0.9**<br>
# d) recall: **0.9**, precisão: **0.79**

# %% [markdown]
# ---
# ### Questão 03.
#
# Qual a técnica de aprendizado de máquina, entre as vistas no curso, cujo aprendizado não é baseado em árvores de decisão?
#
# a) RandomForest<br>
# b) XGBoost<br>
# c) SVM<br>
# d) GBM

# %% [markdown]
# ---
# ### Questão 04.
#
# Se considerarmos 3 classificadores com as seguintes taxas de Falso Positivo e Verdadeiro Positivo:
# - Classificador 1: TFP = 0.3 e TVP = 0.6
# - Classificador 2: TFP = 0.6 e TVP = 0.4
# - Classificador 3: TFP = 0.1 e TVP = 0.7
# Qual deveria ser o classificador escolhido? <br>
#
# a) Classificador 1 <br>
# b) Classificador 2 <br>
# c) Classificador 3 <br>
# d) Nenhum deles <br>

# %% [markdown]
# ---
# ### Questão 05.
#
# Considere um conjunto de dados representados pela imagem abaixo. As cores verde, azul e laranja representam classes nesse conjunto. A cor preta representa um ponto cuja classe é desconhecida.
#
# <img style="width: 500px;" src="data:image/png;base64,..." />
#
# Suponha que foi usado um classificador do tipo KNN com K=11 e distância euclidiana. Qual a classe obtida por esse classificador?
#
# a) Verde<br>
# b) Azul<br>
# c) Laranja<br>
# d) Não é possível afirmar
